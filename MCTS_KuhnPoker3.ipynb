# %% [markdown]
# # Kuhn Poker

# %%
from agents.mcts import MonteCarloTreeSearch
from importlib import reload
import agents
reload(agents)
reload(agents.mcts)

from games.kuhn3 import KuhnPoker3
from agents.agent_random import RandomAgent
from base.utils import play, run
import numpy as np

game = KuhnPoker3(render_mode='human')
reload(agents.mcts)
from agents.mcts import MonteCarloTreeSearch

# %%
agents = dict(map(lambda agent: (agent, MonteCarloTreeSearch(game=game, agent=agent)), game.agents))

# %%
from games.kuhn3 import KuhnPoker3
from agents.agent_random import RandomAgent
from agents.mcts import MonteCarloTreeSearch

game = KuhnPoker3(render_mode='human')
mcts_agent = MonteCarloTreeSearch(game=game, agent='player1')
random_agent = RandomAgent(game=game, agent='player2')

# agents = {'player1': mcts_agent, 'player2': random_agent}
agents = dict(map(lambda agent: (agent, MonteCarloTreeSearch(game=game, agent=agent,simulations=1000)), game.agents))

# Play a single game
winner = run(game=game, agents=agents)
print(f"Winner: {winner}")
# Out:
# agent_0 Q
# agent_1 A
# agent_2 K
# agent_0 Q b
# agent_1 A b
# agent_2 K b
# agent_0 Q bp
# agent_1 A bp
# agent_2 K bp
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# agent_0 Q bpb
# agent_1 A bpb
# agent_2 K bpb
# Game has already finished - Call reset if you want to play again
# agent_0 K
# agent_1 A
# agent_2 J
# agent_0 K b
# agent_1 A b
# agent_2 J b
# agent_0 K bb
# agent_1 A bb
# agent_2 J bb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# agent_0 K bbb
# agent_1 A bbb
# agent_2 J bbb
# ...
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# agent_0 A bpp
# agent_1 K bpp
# agent_2 J bpp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\MCTS_KuhnPoker3.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/MCTS_KuhnPoker3.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> agents = dict(map(lambda agent: (agent, MonteCarloTreeSearch(game=game, agent=agent,simulations=1000)), game.agents))
#      <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/MCTS_KuhnPoker3.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> # Play a single game
# ---> <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/MCTS_KuhnPoker3.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> winner = run(game=game, agents=agents)
#      <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/MCTS_KuhnPoker3.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a> print(f"Winner: {winner}")
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\base\utils.py:19, in run(game, agents, N)
#      17 game.reset()
#      18 while not game.terminated():
# ---> 19     action = agents[game.agent_selection].action()
#      20     game.step(action)
#      21 values.append(game.reward(game.agents[0]))
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\mcts.py:54, in MonteCarloTreeSearch.action(self)
#      53 def action(self) -> ActionType:
# ---> 54     a, _ = self.mcts()
#      55     return a
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\mcts.py:80, in MonteCarloTreeSearch.mcts(self)
#      76 logging.debug(f'Expanded node: {node.action}')
#      77 # Aca podes decir que el nodo sea el nodo nuevo : node = self.expand_node(node)
#      78 # rollout
#      79 #print('rollout')
# ---> 80 rewards = self.rollout(node) # Jugar aleatoriamente y guardar el promedio de las recompensas.
#      81 logging.debug(f'Rollout rewards: {rewards}')
#      82 #update values / Backprop
#      83 #print('backprop')
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\mcts.py:124, in MonteCarloTreeSearch.rollout(self, node)
#     121         action = np.random.choice(available_action)
#     122         game.step(action)
# --> 124     rewards += [game.reward(agent) for agent in self.game.agents]
#     125 #     play random game and record average rewards
#     126 return rewards
#
# KeyboardInterrupt:

# %%
# Or play multiple games
agents = dict(map(lambda agent: (agent, MonteCarloTreeSearch(game=game, agent=agent,simulations=1000,rollouts=1000)), game.agents))

results = [run(game=game, agents=agents, N=1) for _ in range(10)]
# Out:
# agent_0 Q
# agent_1 K
# agent_2 J
# agent_0 Q p
# agent_1 K p
# agent_2 J p
# agent_0 Q pp
# agent_1 K pp
# agent_2 J pp
# agent_0 Q ppb
# agent_1 K ppb
# agent_2 J ppb
# agent_0 Q ppbb
# agent_1 K ppbb
# agent_2 J ppbb
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# agent_0 Q ppbbp
# agent_1 K ppbbp
# agent_2 J ppbbp
# ...
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# agent_0 K pbpb
# agent_1 A pbpb
# agent_2 J pbpb
# Game has already finished - Call reset if you want to play again

# %%
results
# Out:
# [({3: 1}, 3.0),
#  ({-2: 1}, -2.0),
#  ({-1: 1}, -1.0),
#  ({-1: 1}, -1.0),
#  ({2: 1}, 2.0),
#  ({-2: 1}, -2.0),
#  ({2: 1}, 2.0),
#  ({-2: 1}, -2.0),
#  ({-2: 1}, -2.0),
#  ({-2: 1}, -2.0)]

# %%
agents = dict(map(lambda agent: (agent, MonteCarloTreeSearch(game=game, agent=agent)), game.agents))

for agent in agents.values():
    agent.train(niter=100)  # You can adjust the number of iterations
    
run(game=game, agents=agents)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\MCTS_KuhnPoker.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/MCTS_KuhnPoker.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> agents = dict(map(lambda agent: (agent, MonteCarloTreeSearch(game=game, agent=agent)), game.agents))
#       <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/MCTS_KuhnPoker.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> for agent in agents.values():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/MCTS_KuhnPoker.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     agent.train(niter=100)  # You can adjust the number of iterations
#       <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/MCTS_KuhnPoker.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> run(game=game, agents=agents)
#
# AttributeError: 'MonteCarloTreeSearch' object has no attribute 'train'

# %%
game.available_actions()
# Out:
# [0, 1]

# %%
# game.reset()
# game.step(1)
# game.observe('agent_0')

# %%
for n in sorted(agent.node_dict.keys()):
    print(n+'\t', agent.node_dict[n].agent, agent.node_dict[n].policy())
# Out:
# 0	 agent_0 [0.76578406 0.23421594]
# 0b	 agent_1 [0.953125 0.046875]
# 0p	 agent_1 [0.67178271 0.32821729]
# 0pb	 agent_0 [0.98834061 0.01165939]
# 1	 agent_0 [0.44749531 0.55250469]
# 1b	 agent_1 [0.44114524 0.55885476]
# 1p	 agent_1 [0.88475865 0.11524135]
# 1pb	 agent_0 [0.60900197 0.39099803]
# 2	 agent_0 [0.3569576 0.6430424]
# 2b	 agent_1 [0.01388889 0.98611111]
# 2p	 agent_1 [0.01388889 0.98611111]
# 2pb	 agent_0 [0.01795803 0.98204197]

# %%
cum_rewards = dict(map(lambda agent: (agent, 0), game.agents))
niter = 10000
for _ in range(niter):
    game.reset()
    turn = 0
    while not game.done():
        agent.agent = game.agent_selection
        a = agent.action()
        game.step(a)
        turn +=1
    for ag in game.agents:
        cum_rewards[ag] += game.rewards[ag]
print('Average reward:',dict(map(lambda ag : (ag, cum_rewards[ag]/niter), game.agents)))
# Out:
# Average reward: {'agent_0': -0.2035, 'agent_1': 0.2035}
