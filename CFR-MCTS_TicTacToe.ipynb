# %% [markdown]
# # Kuhn Poker

# %%
from agents.counterfactualregret_mcts import CounterFactualRegretMCTS
from importlib import reload
import agents
reload(agents)
reload(agents.counterfactualregret_mcts)

from games.tictactoe import TicTacToe
from agents.agent_random import RandomAgent
from base.utils import play, run
import numpy as np

game = TicTacToe(render_mode='human')
reload(agents.counterfactualregret_mcts)
from agents.counterfactualregret_mcts import CounterFactualRegretMCTS
reload(agents.agent_random)
from agents.agent_random import RandomAgent

# %%
agent_classes = [ CounterFactualRegretMCTS, RandomAgent]
my_agents = {}
for i, agent in enumerate(game.agents):
    my_agents[agent] = agent_classes[i](game=game, agent=agent)

# %%
my_agents
# Out:
# {'player_1': <agents.counterfactualregret_mcts.CounterFactualRegretMCTS at 0x2b53e4a5e50>,
#  'player_2': <agents.agent_random.RandomAgent at 0x2b53e86f050>}

# %%
# agents = {**agents, **dict(map(lambda agent: (agent, RandomAgent(game=game, agent=agent)), game.agents))}

for agent in my_agents.values():
    agent.train(niter=100)  # You can adjust the number of iterations
    
run(game=game, agents=my_agents)
# Out:
# 2023-11-28 22:34:15,967 - DEBUG - Training agent player_1
# 2023-11-28 22:34:15,969 - DEBUG - Entering CFR recursive call, game state: (0, 0, 0, 0, 0, 0, 0, 0, 0)
# 2023-11-28 22:34:15,970 - DEBUG - Agent: player_1
# 2023-11-28 22:34:15,970 - DEBUG - Node agent: player_1
# 2023-11-28 22:34:15,971 - DEBUG - Legal moves: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# 2023-11-28 22:34:15,973 - DEBUG - Attempting action 0 in game state (0, 0, 0, 0, 0, 0, 0, 0, 0)
# 2023-11-28 22:34:15,973 - DEBUG - Node agent: player_2
# 2023-11-28 22:34:15,975 - DEBUG - Legal moves: [1, 2, 3, 4, 5, 6, 7, 8]
# 2023-11-28 22:34:15,976 - DEBUG - Legal moves: [1, 2, 3, 4, 5, 6, 7, 8]
# 2023-11-28 22:34:15,977 - DEBUG - Attempting action 1 in game state (2, 0, 0, 0, 0, 0, 0, 0, 0)
# 2023-11-28 22:34:15,978 - DEBUG - Node agent: player_1
# 2023-11-28 22:34:15,980 - DEBUG - MCTS
# 2023-11-28 22:34:15,981 - DEBUG - Simulation 0
# 2023-11-28 22:34:15,982 - DEBUG - selection
# 2023-11-28 22:34:15,983 - DEBUG - curr_node: None
# 2023-11-28 22:34:15,983 - DEBUG - curr_node.children: []
# 2023-11-28 22:34:15,984 - DEBUG - Selected node: None
# 2023-11-28 22:34:15,987 - DEBUG - Expanded node: None
# 2023-11-28 22:34:15,999 - DEBUG - Rollout rewards: [ 6. -6.]
# 2023-11-28 22:34:16,001 - DEBUG - Simulation 1
# 2023-11-28 22:34:16,001 - DEBUG - selection
# 2023-11-28 22:34:16,002 - DEBUG - curr_node: None
# 2023-11-28 22:34:16,002 - DEBUG - curr_node.children: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>]
# 2023-11-28 22:34:16,003 - DEBUG - visited_child: []
# 2023-11-28 22:34:16,003 - DEBUG - unvisited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>]
# 2023-11-28 22:34:16,005 - DEBUG - curr_node: <agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>
# 2023-11-28 22:34:16,006 - DEBUG - curr_node action: 8
# 2023-11-28 22:34:16,006 - DEBUG - curr_node.explored_children: 1
# 2023-11-28 22:34:16,007 - DEBUG - Selected node: 8
# 2023-11-28 22:34:16,008 - DEBUG - Expanded node: 8
# 2023-11-28 22:34:16,019 - DEBUG - Rollout rewards: [ 2. -2.]
# 2023-11-28 22:34:16,021 - DEBUG - Simulation 2
# 2023-11-28 22:34:16,021 - DEBUG - selection
# 2023-11-28 22:34:16,024 - DEBUG - curr_node: None
# 2023-11-28 22:34:16
- DEBUG - curr_node: None
# 2023-11-28 22:34:16,134 - DEBUG - curr_node.children: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>]
# 2023-11-28 22:34:16,134 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>]
# 2023-11-28 22:34:16,135 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,137 - DEBUG - node.cum_rewards: [  0. -22.]
# 2023-11-28 22:34:16,137 - DEBUG - node.visits: 4
# 2023-11-28 22:34:16,138 - DEBUG - node.parent.visits: 5
# 2023-11-28 22:34:16,138 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:16,139 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86E720>]
# 2023-11-28 22:34:16,140 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,140 - DEBUG - node.cum_rewards: [20.  0.]
# 2023-11-28 22:34:16,143 - DEBUG - node.visits: 3
# 2023-11-28 22:34:16,144 - DEBUG - node.parent.visits: 4
# 2023-11-28 22:34:16,145 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:16,146 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86F6B0>]
# 2023-11-28 22:34:16,148 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,150 - DEBUG - node.cum_rewards: [  0. -18.]
# 2023-11-28 22:34:16,151 - DEBUG - node.visits: 2
# 2023-11-28 22:34:16,152 - DEBUG - node.parent.visits: 3
# 2023-11-28 22:34:16,155 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:16,156 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E6675F0>]
# 2023-11-28 22:34:16,159 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,161 - DEBUG - node.cum_rewards: [10.  0.]
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  X
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  O  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  O
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  O
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  O
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  O
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  X
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  -  |  X
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  X
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  -  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  X  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  O
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  O  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  O  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  -  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  X  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  O  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  O
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  X  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  -
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  O
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  -
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   O  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
# 2023-11-28 22:34:16,163 - DEBUG - node.visits: 1
# 2023-11-28 22:34:16,164 - DEBUG - node.parent.visits: 2
# 2023-11-28 22:34:16,164 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:16,164 - DEBUG - visited_child: []
# 2023-11-28 22:34:16,167 - DEBUG - unvisited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86FA10>]
# 2023-11-28 22:34:16,168 - DEBUG - curr_node: <agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86FA10>
# 2023-11-28 22:34:16,169 - DEBUG - curr_node action: 7
# 2023-11-28 22:34:16,170 - DEBUG - curr_node.explored_children: 1
# 2023-11-28 22:34:16,171 - DEBUG - Selected node: 7
# 2023-11-28 22:34:16,171 - DEBUG - Expanded node: 7
# 2023-11-28 22:34:16,181 - DEBUG - Rollout rewards: [ 10. -10.]
# 2023-11-28 22:34:16,183 - DEBUG - Simulation 6
# 2023-11-28 22:34:16,183 - DEBUG - selection
# 2023-11-28 22:34:16,186 - DEBUG - curr_node: None
# 2023-11-28 22:34:16,187 - DEBUG - curr_node.children: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>]
# 2023-11-28 22:34:16,188 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>]
# 2023-11-28 22:34:16,188 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,190 - DEBUG - node.cum_rewards: [  0. -32.]
# 2023-11-28 22:34:16,190 - DEBUG - node.visits: 5
# 2023-11-28 22:34:16,193 - DEBUG - node.parent.visits: 6
# 2023-11-28 22:34:16,193 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:16,194 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86E720>]
# 2023-11-28 22:34:16,195 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,197 - DEBUG - node.cum_rewards: [30.  0.]
# 2023-11-28 22:34:16,199 - DEBUG - node.visits: 4
# 2023-11-28 22:34:16,200 - DEBUG - node.parent.visits: 5
# 2023-11-28 22:34:16,201 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:16,202 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86F6B0>]
# 2023-11-28 22:34:16,202 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,202 - DEBUG - node.cum_rewards: [  0. -28.]
# 2023-11-28 22:34:16,206 - DEBUG - node.visits: 3
# 2023-11-28 22:34:16,206 - DEBUG - node.parent.visits: 4
# 2023-11-28 22:34:16,207 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:16,208 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E6675F0>]
# 2023-11-28 22:34:16,209 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,209 - DEBUG - node.cum_rewards: [20.  0.]
# 2023-11-28 22:34:16,212 - DEBUG - node.visits: 2
# 2023-11-28 22:34:16,213 - DEBUG - node.parent.visits: 3
# 2023-11-28 22:34:16,214 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:16,215 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86FA10>]
# 2023-11-28 22:34:16,215 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16
- DEBUG - curr_node.children: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>]
# 2023-11-28 22:34:16,309 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E750D10>]
# 2023-11-28 22:34:16,311 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,312 - DEBUG - node.cum_rewards: [  0. -52.]
# 2023-11-28 22:34:16,312 - DEBUG - node.visits: 7
# 2023-11-28 22:34:16,313 - DEBUG - node.parent.visits: 8
# 2023-11-28 22:34:16,313 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:16,314 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86E720>]
# 2023-11-28 22:34:16,315 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,315 - DEBUG - node.cum_rewards: [50.  0.]
# 2023-11-28 22:34:16,318 - DEBUG - node.visits: 6
# 2023-11-28 22:34:16,319 - DEBUG - node.parent.visits: 7
# 2023-11-28 22:34:16,319 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:16,320 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86F6B0>]
# 2023-11-28 22:34:16,322 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,323 - DEBUG - node.cum_rewards: [  0. -48.]
# 2023-11-28 22:34:16,324 - DEBUG - node.visits: 5
# 2023-11-28 22:34:16,325 - DEBUG - node.parent.visits: 6
# 2023-11-28 22:34:16,326 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:16,326 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E6675F0>]
# 2023-11-28 22:34:16,327 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,328 - DEBUG - node.cum_rewards: [40.  0.]
# 2023-11-28 22:34:16,330 - DEBUG - node.visits: 4
# 2023-11-28 22:34:16,332 - DEBUG - node.parent.visits: 5
# 2023-11-28 22:34:16,333 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:16,333 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86FA10>]
# 2023-11-28 22:34:16,334 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,334 - DEBUG - node.cum_rewards: [  0. -30.]
# 2023-11-28 22:34:16,336 - DEBUG - node.visits: 3
# 2023-11-28 22:34:16,337 - DEBUG - node.parent.visits: 4
# 2023-11-28 22:34:16,338 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:16,338 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E635AF0>]
# 2023-11-28 22:34:16,340 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,340 - DEBUG - node.cum_rewards: [20.  0.]
# 2023-11-28 22:34:16,342 - DEBUG - node.visits: 2
# 2023-11-28 22:34:16,343 - DEBUG - node.parent.visits: 3
# 2023-11-28 22:34:16,344 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:16,344 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E8A51F0>]
# 2023-11-28 22:34:16,345 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:16,346 - DEBUG - node.cum_rewards: [  0. -10.]
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   -  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
#      |     |
#      |     |
#   X  |  O  |  O
# _____|_____|_____
#      |     |
#   O  |  O  |  X
# _____|_____|_____
#      |     |
#   X  |  X  |  X
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   O  |  -  |  -
# ...
# 2023-11-28 22:34:57,796 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,797 - DEBUG - node.cum_rewards: [  0. 743.]
# 2023-11-28 22:34:57,798 - DEBUG - node.visits: 76
# 2023-11-28 22:34:57,798 - DEBUG - node.parent.visits: 77
# 2023-11-28 22:34:57,799 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:57,801 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E8F1DC0>]
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  O
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  O
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  O
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  O
#      |     |
# 2023-11-28 22:34:57,803 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,804 - DEBUG - node.cum_rewards: [-744.    0.]
# 2023-11-28 22:34:57,805 - DEBUG - node.visits: 75
# 2023-11-28 22:34:57,806 - DEBUG - node.parent.visits: 76
# 2023-11-28 22:34:57,807 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:57,808 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86C3E0>]
# 2023-11-28 22:34:57,809 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,811 - DEBUG - node.cum_rewards: [  0. 740.]
# 2023-11-28 22:34:57,811 - DEBUG - node.visits: 74
# 2023-11-28 22:34:57,812 - DEBUG - node.parent.visits: 75
# 2023-11-28 22:34:57,812 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:57
- DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,881 - DEBUG - node.cum_rewards: [  0. 767.]
# 2023-11-28 22:34:57,881 - DEBUG - node.visits: 80
# 2023-11-28 22:34:57,883 - DEBUG - node.parent.visits: 81
# 2023-11-28 22:34:57,884 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:57,885 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E8F8590>]
# 2023-11-28 22:34:57,885 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,886 - DEBUG - node.cum_rewards: [-764.    0.]
# 2023-11-28 22:34:57,887 - DEBUG - node.visits: 79
# 2023-11-28 22:34:57,888 - DEBUG - node.parent.visits: 80
# 2023-11-28 22:34:57,890 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:57,891 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E883A40>]
# 2023-11-28 22:34:57,891 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,892 - DEBUG - node.cum_rewards: [  0. 763.]
# 2023-11-28 22:34:57,895 - DEBUG - node.visits: 78
# 2023-11-28 22:34:57,898 - DEBUG - node.parent.visits: 79
# 2023-11-28 22:34:57,898 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:57,899 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E8F1DC0>]
# 2023-11-28 22:34:57,900 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,900 - DEBUG - node.cum_rewards: [-764.    0.]
# 2023-11-28 22:34:57,901 - DEBUG - node.visits: 77
# 2023-11-28 22:34:57,904 - DEBUG - node.parent.visits: 78
# 2023-11-28 22:34:57,905 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:57,905 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E86C3E0>]
# 2023-11-28 22:34:57,907 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,907 - DEBUG - node.cum_rewards: [  0. 760.]
# 2023-11-28 22:34:57,910 - DEBUG - node.visits: 76
# 2023-11-28 22:34:57,910 - DEBUG - node.parent.visits: 77
# 2023-11-28 22:34:57,911 - DEBUG - agent_idx: 1
# 2023-11-28 22:34:57,912 - DEBUG - visited_child: [<agents.counterfactualregret_mcts.MCTSNode object at 0x000002B53E8F1A60>]
# 2023-11-28 22:34:57,912 - DEBUG - unvisited_child: []
# 2023-11-28 22:34:57,913 - DEBUG - node.cum_rewards: [-750.    0.]
# 2023-11-28 22:34:57,914 - DEBUG - node.visits: 75
# 2023-11-28 22:34:57,916 - DEBUG - node.parent.visits: 76
# 2023-11-28 22:34:57,916 - DEBUG - agent_idx: 0
# 2023-11-28 22:34:57,917 - DEBUG - Selected node: 5
# 2023-11-28 22:34:57,917 - DEBUG - Expanded node: 5
# 2023-11-28 22:34:57,925 - DEBUG - Rollout rewards: [-10.  10.]
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  O
#      |     |
#      |     |
#   X  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  -
# _____|_____|_____
#      |     |
#   -  |  -  |  O
#      |     |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\CFR-MCTS_TicTacToe.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/CFR-MCTS_TicTacToe.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # agents = {**agents, **dict(map(lambda agent: (agent, RandomAgent(game=game, agent=agent)), game.agents))}
#       <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/CFR-MCTS_TicTacToe.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> for agent in my_agents.values():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/CFR-MCTS_TicTacToe.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     agent.train(niter=100)  # You can adjust the number of iterations
#       <a href='vscode-notebook-cell:/c%3A/Users/maria/OneDrive/Documents/GitHub/AlternatingGames/CFR-MCTS_TicTacToe.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> run(game=game, agents=my_agents)
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\counterfactualregret_mcts.py:134, in CounterFactualRegretMCTS.train(self, niter)
#     132 # logging.debug(f"Training agent {self.agent}")
#     133 for i in range(niter):
# --> 134     self.cfr()
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\counterfactualregret_mcts.py:150, in CounterFactualRegretMCTS.cfr(self)
#     148 logging.debug(f"Agent: {agent}")
#     149 # self.utilities[agent] =
# --> 150 self.cfr_rec(game=game, agent=agent, probability=probability)
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\counterfactualregret_mcts.py:212, in CounterFactualRegretMCTS.cfr_rec(self, game, agent, probability, depth)
#     209     game_clone.step(a)
#     210     # call cfr recursively on updated game with new probability and update node utility
# --> 212     utility[a] = self.cfr_rec(game_clone, agent, probability_new,depth=depth+1)
#     214 node_utility = np.sum(utility * node.curr_policy) # Valor esperado de la probabilidad de la
#     215 # vI = vI + πI [a] ∗ vI→a[a]
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\counterfactualregret_mcts.py:212, in CounterFactualRegretMCTS.cfr_rec(self, game, agent, probability, depth)
#     209     game_clone.step(a)
#     210     # call cfr recursively on updated game with new probability and update node utility
# --> 212     utility[a] = self.cfr_rec(game_clone, agent, probability_new,depth=depth+1)
#     214 node_utility = np.sum(utility * node.curr_policy) # Valor esperado de la probabilidad de la
#     215 # vI = vI + πI [a] ∗ vI→a[a]
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\counterfactualregret_mcts.py:166, in CounterFactualRegretMCTS.cfr_rec(self, game, agent, probability, depth)
#     163 if depth >= self.max_depth:
#     164     # Use MCTS for utility estimation
#     165     mcts_root = MCTSNode(parent=None, game=game, action=None)
# --> 166     _, estimated_utility = self.mcts(game, simulations=100)
#     167     return estimated_utility  # Or further processing depending on your game's nature
#     169 # if self.depth == 0:
#     170 #     return function_evaluacion(self.tipo_funcion, game, agent) # no quiero hacer regret entonces uso una estimacion. La mas rapida es rollout.
#     171 # # implementar aca montecarlo tree search, rollout(monte carlo), heuristica.
#     172
#     173 # get observation node
#
# File c:\Users\maria\OneDrive\Documents\GitHub\AlternatingGames\agents\counterfactualregret_mcts.py:264, in CounterFactualRegretMCTS.mcts(self, game, simulations)
#     260 # Aca podes decir que el nodo sea el nodo nuevo : node = self.expand_node(node)
#     261 # rollout
#     262 #print('rollout')
#     263 rewards = self.rollout(node) # Jugar aleatoriamente y guardar el promedio de las recompensas.
# --> 264 logging.debug(f'Rollout rewards: {rewards}')
#     265 #update values / Backprop
#     266 #print('backprop')
#     267 self.backprop(node, rewards)
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\logging\__init__.py:2233, in debug(msg, *args, **kwargs)
#    2231 if len(root.handlers) == 0:
#    2232     basicConfig()
# -> 2233 root.debug(msg, *args, **kwargs)
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\logging\__init__.py:1527, in Logger.debug(self, msg, *args, **kwargs)
#    1518 """
#    1519 Log 'msg % args' with severity 'DEBUG'.
#    1520
#    (...)
#    1524 logger.debug("Houston, we have a %s", "thorny problem", exc_info=1)
#    1525 """
#    1526 if self.isEnabledFor(DEBUG):
# -> 1527     self._log(DEBUG, msg, args, **kwargs)
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\logging\__init__.py:1684, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1681         exc_info = sys.exc_info()
#    1682 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1683                          exc_info, func, extra, sinfo)
# -> 1684 self.handle(record)
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\logging\__init__.py:1700, in Logger.handle(self, record)
#    1698 if isinstance(maybe_record, LogRecord):
#    1699     record = maybe_record
# -> 1700 self.callHandlers(record)
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\logging\__init__.py:1762, in Logger.callHandlers(self, record)
#    1760     found = found + 1
#    1761     if record.levelno >= hdlr.level:
# -> 1762         hdlr.handle(record)
#    1763 if not c.propagate:
#    1764     c = None    #break out
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\logging\__init__.py:1028, in Handler.handle(self, record)
#    1026 self.acquire()
#    1027 try:
# -> 1028     self.emit(record)
#    1029 finally:
#    1030     self.release()
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\logging\__init__.py:1163, in StreamHandler.emit(self, record)
#    1161     stream = self.stream
#    1162     # issue 35046: merged two stream.writes into one.
# -> 1163     stream.write(msg + self.terminator)
#    1164     self.flush()
#    1165 except RecursionError:  # See issue 36272
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\site-packages\ipykernel\iostream.py:664, in OutStream.write(self, string)
#     662         self.pub_thread.schedule(self._flush)
#     663     else:
# --> 664         self._schedule_flush()
#     666 return len(string)
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\site-packages\ipykernel\iostream.py:561, in OutStream._schedule_flush(self)
#     558 def _schedule_in_thread():
#     559     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 561 self.pub_thread.schedule(_schedule_in_thread)
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\site-packages\ipykernel\iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\site-packages\zmq\sugar\socket.py:696, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     689         data = zmq.Frame(
#     690             data,
#     691             track=track,
#     692             copy=copy or None,
#     693             copy_threshold=self.copy_threshold,
#     694         )
#     695     data.group = group
# --> 696 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:742, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:789, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:250, in zmq.backend.cython.socket._send_copy()
#
# File c:\Users\maria\anaconda3\envs\RL\Lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
game.available_actions()
# Out:
# [0, 1]

# %%
# game.reset()
# game.step(1)
# game.observe('agent_0')

# %%
# for n in sorted(agent.node_dict.keys()):
#     print(n+'\t', agent.node_dict[n].agent, agent.node_dict[n].policy())

for agent in my_agents.values():
    if hasattr(agent, 'node_dict'):
        for n in sorted(agent.node_dict.keys()):
            print(n + '\t', agent.node_dict[n].agent, agent.node_dict[n].policy())
    else:
        print(f"{agent} does not have a node_dict attribute.")
# Out:
# 0	 agent_0 [0.76957461 0.23042539]
# 0b	 agent_1 [0.984375 0.015625]
# 0p	 agent_1 [0.57782048 0.42217952]
# 0pb	 agent_0 [0.99145119 0.00854881]
# 1	 agent_0 [0.82445145 0.17554855]
# 1b	 agent_1 [0.46491872 0.53508128]
# 1p	 agent_1 [0.72086833 0.27913167]
# 1pb	 agent_0 [0.42354809 0.57645191]
# 2	 agent_0 [0.18062077 0.81937923]
# 2b	 agent_1 [0.015625 0.984375]
# 2p	 agent_1 [0.015625 0.984375]
# 2pb	 agent_0 [0.0494327 0.9505673]
# <agents.agent_random.RandomAgent object at 0x00000245FA717090> does not have a node_dict attribute.

# %%
cum_rewards = dict(map(lambda agent: (agent, 0), game.agents))
niter = 100000
for _ in range(niter):
    game.reset()
    turn = 0
    while not game.done():
        agent.agent = game.agent_selection
        a = agent.action()
        game.step(a)
        turn +=1
    for ag in game.agents:
        cum_rewards[ag] += game.rewards[ag]
print('Average reward:',dict(map(lambda ag : (ag, cum_rewards[ag]/niter), game.agents)))
print('Agent mapping:',my_agents)
# Out:
# Average reward: {'agent_0': 0.13081, 'agent_1': -0.13081}
# Agent mapping: {'agent_0': <agents.counterfactualregret.CounterFactualRegret object at 0x0000026A18567E10>, 'agent_1': <agents.agent_random.RandomAgent object at 0x0000026A7FE4EC90>}
